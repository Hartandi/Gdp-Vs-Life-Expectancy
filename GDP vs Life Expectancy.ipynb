# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
database = pd.read_csv("D:\Python\DataCamp\Python Intermediate\gapminder1.csv",sep = ";")

# %%
database
# Out:
#      Unnamed: 0             #VALUE!  YEAR  POPULATION      CONT  life_exp  \
# 0             1         Afghanistan  2007    31889923      Asia    43.828
# 1             2             Albania  2007     3600523    Europe    76.423
# 2             3             Algeria  2007    33333216    Africa    72.301
# 3             4              Angola  2007    12420476    Africa    42.731
# 4             5           Argentina  2007    40301927  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137         138             Vietnam  2007    85262356      Asia    74.249
# 138         139  West Bank and Gaza  2007     4018332      Asia    73.422
# 139         140         Yemen, Rep.  2007    22211743      Asia    62.698
# 140         141              Zambia  2007    11746035    Africa    42.384
# 141         142            Zimbabwe  2007    12311143    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# ...

# %%
gdp = database['gdp_cap']
life = database['life_exp']
pop = database['POPULATION']

# %%
plt.title("GDP vs Life Expetancy")
plt.xlabel("GDP")
plt.ylabel("Life Expetancy")
plt.style.use('seaborn')
plt.scatter(gdp,life,c=life,cmap = "Spectral")
plt.colorbar(orientation='horizontal')
plt.savefig("plot 1.png", dpi = 800, bbox_inches="tight")
